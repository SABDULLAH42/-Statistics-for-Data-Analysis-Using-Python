# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# Ex: A sample of 51 bottles was selected. The standard deviation of these 51 bottles was 2.35 cc.
# Has it increased from the established 2cc? 90% confidence level

# %%
Chi_sq_cal = (n-1)s^2 / sigma^2

# %%
x_ax = np.linspace(0, 100, 101)
y_ax = stats.chi2.pdf(x_ax, df=50)  # pdf gives you the vertical distance or the Y axis value for the chi-sq distribution

# %%
sns.relplot(x=x_ax, y=y_ax, kind='line')

# %%
Chi_sq_cal = (n-1)s^2 / sigma^2

# %%
Chi_sq_cal = (51-1) * (2.35**2) / (2**2)

# %%
Chi_sq_cal
# Out:
# 69.03125000000001

# %%
stats.chi2.isf(0.10, 50) # Calculated value is 69, which is more than the critical value and hence 
                           # we will reject the Null hypotheses
    
    
                         # isf will give you the value of chi-sq for which the area on the roght is 0.10
                         # dof must be there in the Chi-square distribution
# Out:
# 63.167121005726315

# %% [markdown]
# ### Rejecting Null hypothesis means that there is a significant diff in the variance or the SD of these sample

# %%
# Question 1:
# The average breaking strength of steel rods is required to be at least 35,000 psi. 
# Based on the historical information the standard deviation of breaking strength is 1,500 psi. 
# A random sample of four specimens had the strengths as: piece one 32,000, piece two 36,000, piece three 34,000 
# and piece four 34,500.

# What will be the null and alternate hypothesis in this case?

# %%
#Null hypotheses >= 35000 psi and Alternate hypotheses < 35000 psi
